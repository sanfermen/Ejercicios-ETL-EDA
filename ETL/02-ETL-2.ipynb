# %%
import pandas as pd
import numpy as np
import requests
import ast

pd.options.display.max_columns = None

# %% [markdown]
# # Pair Programming ETL Transformación I
#
# Tendréis que usar el csv attacks_limpieza_completa que tenéis adjunto abajo.
#
# En la lección de hoy aprendimos como transformar nuestros datos para que estén preparados para almacearlos en una BBDD. En este momento tenemos dos fuentes de datos:
#
#     1. El csv con los ataques de tiburones que hemos estado limpiando hasta ahora, el que os hemos adjuntado (attacks_limpieza_completa). Sentiros libres de usar vuestros propios csv en caso de que queráis.
#
#     2. El csv con los datos climáticos de los principales paises que tienen ataques de tiburones, el que creamos en el pair programming de ayer.
#
# El objetivo de la sesión de hoy será juntar en un único csv la información de ambas fuentes. Para ello:
#
# - Cargaremos los dos ficheros de datos
# - Del dataframe de los ataques nos quedaremos solo con las filas de los países que seleccionamos en la lección de ayer:
#
#     - USA
#     - Australia
#     - New Zealand
#     - South Africa
#     - Papua New Guinea
#
# - Del dataframe de los datos climáticos seleccionaremos todas las columnas.
#
# - Cuando ya tengamos todos los datos deseados juntaremos los dos csv.
# Para hacer esta unión tendremos que hacer un groupby en la tabla de clima para sacar una media de las medidas climáticas por país.
#
# - Antes de hacer el groupby si nos fijamos tenemos dos columnas rh_profile y wind_profile cuya información es una lista de diccionarios. Si intentamos hacer la media de eso no nos dará un valor real. A este problema ya nos enfrentamos en la clase invertida de ETL-2, donde teníais un Bonus para desempaquetar esta información. En caso de que en aquel ejercicio no lo consigierais os dejamos por aquí una posible solución que nos permite separar esa información en distintas columnas. Os dejamos el código documentado. ⚠️ Os recomendamos que vayáis desgranando el código y viendo lo que nos devuelve cada línea de código para entenderlo mejor.

# %%
# Cargamos el df de los ataques
df = pd.read_csv("../data/05-tiburon_4.csv", index_col = 0)

# %%
df.head()
# Out:
#          type    country        activity      species month fatal gender  \
# 0     Boating        usa        Paddling        White   Jun     N      F
# 1  Unprovoked     brazil        Swimming        Tiger   Jun     Y      M
# 2  Unprovoked        usa         Walking         Bull   May     N      M
# 3    Provoked  australia  Feeding sharks         Grey   May     N      M
# 4     Invalid    england         Fishing  Unspecified   May     N      M
#
#      year   age
# 0  2018.0  57.0
# 1  2018.0  18.0
# 2  2018.0  15.0
# 3  2018.0  32.0
# 4  2018.0  21.0

# %%
# Cargamos el dataframe del clima
df_clima = pd.read_csv("../data/00-datos_clima.csv", index_col = 0)

# %%
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           7      -9999     -9999     -9999
# 1          6           8      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 6}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 150, 'speed':...      16             6
# 1  [{'layer': '950mb', 'direction': 265, 'speed':...      15             6
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     4          1024      none            0           0                110
# 1     6          1025      none            0           0                220
#
#    wind10m.speed country   latitud    longitud
# 0              2     usa  39.78373 -100.445882
# 1              2     usa  39.78373 -100.445882

# %%
# Hacemos una lista solo con los paises que hay en el df del clima
lista_paises = df_clima["country"].unique().tolist()
lista_paises
# Out:
# ['usa', 'australia', 'south africa', 'new zealand', 'papua new guinea']

# %%
# Creamos un dataframe filtrando el df de los ataques con los paises que están en clima
df_pais = df[df["country"].isin(lista_paises)]
df_pais.head()
# Out:
#          type       country        activity      species month fatal gender  \
# 0     Boating           usa        Paddling        White   Jun     N      F
# 2  Unprovoked           usa         Walking         Bull   May     N      M
# 3    Provoked     australia  Feeding sharks         Grey   May     N      M
# 6  Unprovoked     australia         Surfing  Unspecified   Apr     N      M
# 8  Unprovoked  south africa   Paddle-skiing        White   Apr     N      M
#
#      year   age
# 0  2018.0  57.0
# 2  2018.0  15.0
# 3  2018.0  32.0
# 6  2018.0  60.0
# 8  2018.0  33.0

# %%
# Hacemos que dentro de la columna haya listas que podamos separar por columnas
df_clima["rh_profile"] = df_clima["rh_profile"].apply(ast.literal_eval)
df_clima["wind_profile"] = df_clima["wind_profile"].apply(ast.literal_eval)

# %%
# Ahora podremos separar la columna en diferentes columnas, una por cada diccionario
df_rh = df_clima["rh_profile"].apply(pd.Series)
df_rh.head(2)
# Out:
#                             0                            1   \
# 0  {'layer': '950mb', 'rh': 5}  {'layer': '900mb', 'rh': 7}
# 1  {'layer': '950mb', 'rh': 6}  {'layer': '900mb', 'rh': 7}
#
#                             2                             3   \
# 0  {'layer': '850mb', 'rh': 8}  {'layer': '800mb', 'rh': 13}
# 1  {'layer': '850mb', 'rh': 6}   {'layer': '800mb', 'rh': 8}
#
#                              4                            5   \
# 0  {'layer': '750mb', 'rh': 11}  {'layer': '700mb', 'rh': 7}
# 1  {'layer': '750mb', 'rh': 11}  {'layer': '700mb', 'rh': 6}
#
#                             6                            7   \
# 0  {'layer': '650mb', 'rh': 3}  {'layer': '600mb', 'rh': 1}
# 1  {'layer': '650mb', 'rh': 3}  {'layer': '600mb', 'rh': 8}
#
#                              8                             9   \
# 0   {'layer': '550mb', 'rh': 3}  {'layer': '500mb', 'rh': 10}
# 1  {'layer': '550mb', 'rh': 15}  {'layer': '500mb', 'rh': 16}
#
#                              10                            11  \
# 0  {'layer': '450mb', 'rh': 11}  {'layer': '400mb', 'rh': 11}
# 1  {'layer': '450mb', 'rh': 16}  {'layer': '400mb', 'rh': 16}
#
#                              12                            13  \
# 0  {'layer': '350mb', 'rh': 13}  {'layer': '300mb', 'rh': 15}
# 1  {'layer': '350mb', 'rh': 16}  {'layer': '300mb', 'rh': 12}
#
#                              14                            15
# 0  {'layer': '250mb', 'rh': 15}  {'layer': '200mb', 'rh': 14}
# 1  {'layer': '250mb', 'rh': 14}   {'layer': '200mb', 'rh': 6}

# %%
df_clima.shape[1]
# Out:
# 19

# %%
for i in range(len(df_rh.columns)):
    #Aplicamos el apply y extraemos el valor de la key "layer" y lo almacenamos en una variable que convertimos a string
    nombre = "rh_" + str(df_rh[i].apply(pd.Series)["layer"][0])
    # hacemos lo mismo con una variable que se llame valores para "guardar" los valores de la celda
    valores = list(df_rh[i].apply(pd.Series)["rh"])
    # usamos el método insert de los dataframes para ir añadiendo esta información a el dataframe con la información del clima.
    df_clima.insert(i, nombre, valores)

# %%
df_clima.head(1)
# Out:
#    rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  rh_650mb  \
# 0         5         7         8        13        11         7         3
#
#    rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  rh_350mb  rh_300mb  \
# 0         1         3        10        11        11        13        15
#
#    rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0        15        14          3           7      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 150, 'speed':...      16             6
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     4          1024      none            0           0                110
#
#    wind10m.speed country   latitud    longitud
# 0              2     usa  39.78373 -100.445882

# %%
# Hacemos lo mismo en la columna Wind_profile
df_wind = df_clima["wind_profile"].apply(pd.Series)
df_wind.head(2)
# Out:
#                                                  0   \
# 0  {'layer': '950mb', 'direction': 150, 'speed': 2}
# 1  {'layer': '950mb', 'direction': 265, 'speed': 2}
#
#                                                  1   \
# 0  {'layer': '900mb', 'direction': 240, 'speed': 2}
# 1  {'layer': '900mb', 'direction': 330, 'speed': 3}
#
#                                                  2   \
# 0  {'layer': '850mb', 'direction': 260, 'speed': 3}
# 1  {'layer': '850mb', 'direction': 340, 'speed': 4}
#
#                                                  3   \
# 0  {'layer': '800mb', 'direction': 275, 'speed': 3}
# 1  {'layer': '800mb', 'direction': 340, 'speed': 3}
#
#                                                  4   \
# 0  {'layer': '750mb', 'direction': 280, 'speed': 4}
# 1  {'layer': '750mb', 'direction': 325, 'speed': 3}
#
#                                                  5   \
# 0  {'layer': '700mb', 'direction': 265, 'speed': 5}
# 1  {'layer': '700mb', 'direction': 305, 'speed': 3}
#
#                                                  6   \
# 0  {'layer': '650mb', 'direction': 270, 'speed': 5}
# 1  {'layer': '650mb', 'direction': 295, 'speed': 4}
#
#                                                  7   \
# 0  {'layer': '600mb', 'direction': 265, 'speed': 6}
# 1  {'layer': '600mb', 'direction': 275, 'speed': 6}
#
#                                                  8   \
# 0  {'layer': '550mb', 'direction': 255, 'speed': 6}
# 1  {'layer': '550mb', 'direction': 265, 'speed': 6}
#
#                                                  9   \
# 0  {'layer': '500mb', 'direction': 250, 'speed': 6}
# 1  {'layer': '500mb', 'direction': 260, 'speed': 6}
#
#                                                  10  \
# 0  {'layer': '450mb', 'direction': 245, 'speed': 6}
# 1  {'layer': '450mb', 'direction': 250, 'speed': 7}
#
#                                                  11  \
# 0  {'layer': '400mb', 'direction': 250, 'speed': 6}
# 1  {'layer': '400mb', 'direction': 255, 'speed': 7}
#
#                                                  12  \
# 0  {'layer': '350mb', 'direction': 250, 'speed': 6}
# 1  {'layer': '350mb', 'direction': 255, 'speed': 7}
#
#                                                  13  \
# 0  {'layer': '300mb', 'direction': 250, 'speed': 7}
# 1  {'layer': '300mb', 'direction': 245, 'speed': 7}
#
#                                                  14  \
# 0  {'layer': '250mb', 'direction': 245, 'speed': 7}
# 1  {'layer': '250mb', 'direction': 250, 'speed': 7}
#
#                                                  15
# 0  {'layer': '200mb', 'direction': 250, 'speed': 7}
# 1  {'layer': '200mb', 'direction': 255, 'speed': 7}

# %%
for i in range(len(df_wind.columns)):
    #Aplicamos el apply y extraemos el valor de la key "layer" y lo almacenamos en una variable que convertimos a string
    nombre = "wind_direction" + str(df_wind[i].apply(pd.Series)["layer"][0])
    # hacemos lo mismo con una variable que se llame valores para "guardar" los valores de la celda
    valores = list(df_wind[i].apply(pd.Series)["direction"])
    # usamos el método insert de los dataframes para ir añadiendo esta información a el dataframe con la información del clima.
    df_clima.insert(i, nombre, valores)

# %%
for i in range(len(df_wind.columns)):
    # Hacemos lo mismo para speed
    nombre2= "wind_speed" + str(df_wind[i].apply(pd.Series)["layer"][0])
    valores2 = list(df_wind[i].apply(pd.Series)["speed"])
    # usamos el método insert de los dataframes para ir añadiendo esta información a el dataframe con la información del clima.
    df_clima.insert(i, nombre2, valores2)

# %%
df_clima.head(2)
# Out:
#    wind_speed950mb  wind_speed900mb  wind_speed850mb  wind_speed800mb  \
# 0                2                2                3                3
# 1                2                3                4                3
#
#    wind_speed750mb  wind_speed700mb  wind_speed650mb  wind_speed600mb  \
# 0                4                5                5                6
# 1                3                3                4                6
#
#    wind_speed550mb  wind_speed500mb  wind_speed450mb  wind_speed400mb  \
# 0                6                6                6                6
# 1                6                6                7                7
#
#    wind_speed350mb  wind_speed300mb  wind_speed250mb  wind_speed200mb  \
# 0                6                7                7                7
# 1                7                7                7                7
#
#    wind_direction950mb  wind_direction900mb  wind_direction850mb  \
# 0                  150                  240                  260
# 1                  265                  330                  340
#
#    wind_direction800mb  wind_direction750mb  wind_direction700mb  \
# 0                  275                  280                  265
# 1                  340                  325                  305
#
#    wind_direction650mb  wind_direction600mb  wind_direction550mb  \
# 0                  270                  265                  255
# 1                  295                  275                  265
#
#    wind_direction500mb  wind_direction450mb  wind_direction400mb  \
# 0                  250                  245                  250
# 1                  260                  250                  255
#
#    wind_direction350mb  wind_direction300mb  wind_direction250mb  \
# 0                  250                  250                  245
# 1                  255                  245                  250
#
#    wind_direction200mb  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  \
# 0                  250         5         7         8        13        11
# 1                  255         6         7         6         8        11
#
#    rh_700mb  rh_650mb  rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  \
# 0         7         3         1         3        10        11        11
# 1         6         3         8        15        16        16        16
#
#    rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  \
# 0        13        15        15        14          3           7      -9999
# 1        16        12        14         6          6           8      -9999
#
#    midcloud  lowcloud                                         rh_profile  \
# 0     -9999     -9999  [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 1     -9999     -9999  [{'layer': '950mb', 'rh': 6}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 150, 'speed':...      16             6
# 1  [{'layer': '950mb', 'direction': 265, 'speed':...      15             6
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m.direction  \
# 0     4          1024      none            0           0                110
# 1     6          1025      none            0           0                220
#
#    wind10m.speed country   latitud    longitud
# 0              2     usa  39.78373 -100.445882
# 1              2     usa  39.78373 -100.445882

# %%
# Borramos las columnas rh_profile y wind_profile que ya no nos sirven
df_clima.drop(["rh_profile", "wind_profile"], axis= 1, inplace= True)

# %%
df_clima.head(1)
# Out:
#    wind_speed950mb  wind_speed900mb  wind_speed850mb  wind_speed800mb  \
# 0                2                2                3                3
#
#    wind_speed750mb  wind_speed700mb  wind_speed650mb  wind_speed600mb  \
# 0                4                5                5                6
#
#    wind_speed550mb  wind_speed500mb  wind_speed450mb  wind_speed400mb  \
# 0                6                6                6                6
#
#    wind_speed350mb  wind_speed300mb  wind_speed250mb  wind_speed200mb  \
# 0                6                7                7                7
#
#    wind_direction950mb  wind_direction900mb  wind_direction850mb  \
# 0                  150                  240                  260
#
#    wind_direction800mb  wind_direction750mb  wind_direction700mb  \
# 0                  275                  280                  265
#
#    wind_direction650mb  wind_direction600mb  wind_direction550mb  \
# 0                  270                  265                  255
#
#    wind_direction500mb  wind_direction450mb  wind_direction400mb  \
# 0                  250                  245                  250
#
#    wind_direction350mb  wind_direction300mb  wind_direction250mb  \
# 0                  250                  250                  245
#
#    wind_direction200mb  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  \
# 0                  250         5         7         8        13        11
#
#    rh_700mb  rh_650mb  rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  \
# 0         7         3         1         3        10        11        11
#
#    rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  \
# 0        13        15        15        14          3           7      -9999
#
#    midcloud  lowcloud  temp2m  lifted_index  rh2m  msl_pressure prec_type  \
# 0     -9999     -9999      16             6     4          1024      none
#
#    prec_amount  snow_depth  wind10m.direction  wind10m.speed country  \
# 0            0           0                110              2     usa
#
#     latitud    longitud
# 0  39.78373 -100.445882

# %%
# Hacemos un groupby por pais y sacamos la media
df_media_c = df_clima.groupby("country").mean().reset_index()
# Out:
# /tmp/ipykernel_1383/850632413.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_media_c = df_clima.groupby("country").mean().reset_index()

# %%
df_media_c.head(2)
# Out:
#        country  wind_speed950mb  wind_speed900mb  wind_speed850mb  \
# 0    australia          3.56250         3.578125         3.546875
# 1  new zealand          3.34375         3.234375         3.171875
#
#    wind_speed800mb  wind_speed750mb  wind_speed700mb  wind_speed650mb  \
# 0         3.515625         3.421875           3.5000         3.515625
# 1         3.156250         3.187500           3.1875         3.281250
#
#    wind_speed600mb  wind_speed550mb  wind_speed500mb  wind_speed450mb  \
# 0         3.546875         3.656250         3.593750          3.59375
# 1         3.421875         3.546875         3.796875          4.03125
#
#    wind_speed400mb  wind_speed350mb  wind_speed300mb  wind_speed250mb  \
# 0         3.546875          3.56250         3.921875         4.734375
# 1         4.234375          4.65625         5.015625         6.265625
#
#    wind_speed200mb  wind_direction950mb  wind_direction900mb  \
# 0         5.203125            79.921875            80.546875
# 1         7.218750           141.875000           143.437500
#
#    wind_direction850mb  wind_direction800mb  wind_direction750mb  \
# 0           101.093750           102.109375           103.828125
# 1           147.421875           155.390625           179.609375
#
#    wind_direction700mb  wind_direction650mb  wind_direction600mb  \
# 0            99.609375           106.406250            96.796875
# 1           190.703125           192.890625           212.421875
#
#    wind_direction550mb  wind_direction500mb  wind_direction450mb  \
# 0             88.90625            80.468750            82.968750
# 1            230.62500           241.796875           255.546875
#
#    wind_direction400mb  wind_direction350mb  wind_direction300mb  \
# 0            89.921875           121.953125           129.921875
# 1           269.218750           264.921875           255.156250
#
#    wind_direction250mb  wind_direction200mb   rh_950mb   rh_900mb  rh_850mb  \
# 0           139.296875           142.109375  13.890625  11.437500  8.484375
# 1           251.953125           260.312500  13.171875  12.546875  4.625000
#
#    rh_800mb  rh_750mb  rh_700mb  rh_650mb  rh_600mb  rh_550mb  rh_500mb  \
# 0  6.375000  5.296875   4.46875  3.796875   3.40625  3.078125  3.375000
# 1  2.578125  2.484375   2.81250  3.062500   3.00000  2.718750  2.828125
#
#    rh_450mb  rh_400mb  rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  \
# 0  3.375000  3.203125  2.453125  1.390625  3.562500  5.843750       97.5
# 1  2.734375  3.875000  5.656250  7.093750  4.984375  1.640625       97.5
#
#    cloudcover  highcloud  midcloud  lowcloud     temp2m  lifted_index  \
# 0    2.640625    -9999.0   -9999.0   -9999.0  25.875000     -3.828125
# 1    6.093750    -9999.0   -9999.0   -9999.0  14.953125     10.265625
#
#         rh2m  msl_pressure  prec_amount  snow_depth  wind10m.direction  \
# 0  10.828125    1015.93750     2.796875         0.0          80.859375
# 1  10.296875    1020.90625     2.671875         0.0         133.828125
#
#    wind10m.speed    latitud    longitud
# 0       3.296875 -24.776109  134.755000
# 1       3.015625 -41.500083  172.834408

# %%
df_pais.head(2)
# Out:
#          type country  activity species month fatal gender    year   age
# 0     Boating     usa  Paddling   White   Jun     N      F  2018.0  57.0
# 2  Unprovoked     usa   Walking    Bull   May     N      M  2018.0  15.0

# %%
# Unimos el dataframe con las medias del clima por pais, con el df de los ataques
df_pais_clima = pd.merge(df_pais, df_media_c, on = "country", how= "left")

# %%
df_pais_clima.head()
# Out:
#          type       country        activity      species month fatal gender  \
# 0     Boating           usa        Paddling        White   Jun     N      F
# 1  Unprovoked           usa         Walking         Bull   May     N      M
# 2    Provoked     australia  Feeding sharks         Grey   May     N      M
# 3  Unprovoked     australia         Surfing  Unspecified   Apr     N      M
# 4  Unprovoked  south africa   Paddle-skiing        White   Apr     N      M
#
#      year   age  wind_speed950mb  wind_speed900mb  wind_speed850mb  \
# 0  2018.0  57.0           2.8750         3.265625         3.750000
# 1  2018.0  15.0           2.8750         3.265625         3.750000
# 2  2018.0  32.0           3.5625         3.578125         3.546875
# 3  2018.0  60.0           3.5625         3.578125         3.546875
# 4  2018.0  33.0           2.5000         2.359375         2.234375
#
#    wind_speed800mb  wind_speed750mb  wind_speed700mb  wind_speed650mb  \
# 0         4.156250         4.328125         4.421875         4.609375
# 1         4.156250         4.328125         4.421875         4.609375
# 2         3.515625         3.421875         3.500000         3.515625
# 3         3.515625         3.421875         3.500000         3.515625
# 4         2.156250         2.187500         2.140625         2.375000
#
#    wind_speed600mb  wind_speed550mb  wind_speed500mb  wind_speed450mb  \
# 0         5.000000         5.281250         5.625000         6.015625
# 1         5.000000         5.281250         5.625000         6.015625
# 2         3.546875         3.656250         3.593750         3.593750
# 3         3.546875         3.656250         3.593750         3.593750
# 4         2.484375         2.734375         2.984375         3.546875
#
#    wind_speed400mb  wind_speed350mb  wind_speed300mb  wind_speed250mb  \
# 0         6.375000         6.890625         7.687500         8.250000
# 1         6.375000         6.890625         7.687500         8.250000
# 2         3.546875         3.562500         3.921875         4.734375
# 3         3.546875         3.562500         3.921875         4.734375
# 4         3.703125         4.015625         4.140625         4.531250
#
#    wind_speed200mb  wind_direction950mb  wind_direction900mb  \
# 0         8.406250           234.687500           265.546875
# 1         8.406250           234.687500           265.546875
# 2         5.203125            79.921875            80.546875
# 3         5.203125            79.921875            80.546875
# 4         4.843750           150.078125           191.250000
#
#    wind_direction850mb  wind_direction800mb  wind_direction750mb  \
# 0           301.328125           313.203125           287.265625
# 1           301.328125           313.203125           287.265625
# 2           101.093750           102.109375           103.828125
# 3           101.093750           102.109375           103.828125
# 4           182.656250           179.296875           204.296875
#
#    wind_direction700mb  wind_direction650mb  wind_direction600mb  \
# 0           305.625000           291.328125           294.453125
# 1           305.625000           291.328125           294.453125
# 2            99.609375           106.406250            96.796875
# 3            99.609375           106.406250            96.796875
# 4           222.031250           224.609375           220.703125
#
#    wind_direction550mb  wind_direction500mb  wind_direction450mb  \
# 0            293.12500            293.43750            292.96875
# 1            293.12500            293.43750            292.96875
# 2             88.90625             80.46875             82.96875
# 3             88.90625             80.46875             82.96875
# 4            228.12500            230.78125            232.81250
#
#    wind_direction400mb  wind_direction350mb  wind_direction300mb  \
# 0           288.437500           292.968750           284.375000
# 1           288.437500           292.968750           284.375000
# 2            89.921875           121.953125           129.921875
# 3            89.921875           121.953125           129.921875
# 4           237.187500           233.828125           230.078125
#
#    wind_direction250mb  wind_direction200mb   rh_950mb   rh_900mb  rh_850mb  \
# 0           274.140625           304.687500   4.375000   5.140625  5.656250
# 1           274.140625           304.687500   4.375000   5.140625  5.656250
# 2           139.296875           142.109375  13.890625  11.437500  8.484375
# 3           139.296875           142.109375  13.890625  11.437500  8.484375
# 4           223.437500           216.250000  12.921875   9.718750  8.015625
#
#    rh_800mb  rh_750mb  rh_700mb   rh_650mb  rh_600mb  rh_550mb  rh_500mb  \
# 0  4.718750  3.187500   2.59375   2.296875   2.18750  2.937500   4.00000
# 1  4.718750  3.187500   2.59375   2.296875   2.18750  2.937500   4.00000
# 2  6.375000  5.296875   4.46875   3.796875   3.40625  3.078125   3.37500
# 3  6.375000  5.296875   4.46875   3.796875   3.40625  3.078125   3.37500
# 4  8.609375  9.437500   9.81250  10.203125   8.18750  5.796875   4.78125
#
#    rh_450mb  rh_400mb  rh_350mb  rh_300mb  rh_250mb  rh_200mb  timepoint  \
# 0  4.578125  4.921875  5.312500  6.140625  7.296875  5.984375       97.5
# 1  4.578125  4.921875  5.312500  6.140625  7.296875  5.984375       97.5
# 2  3.375000  3.203125  2.453125  1.390625  3.562500  5.843750       97.5
# 3  3.375000  3.203125  2.453125  1.390625  3.562500  5.843750       97.5
# 4  3.312500  2.125000  2.984375  3.796875  5.218750  7.765625       97.5
#
#    cloudcover  highcloud  midcloud  lowcloud   temp2m  lifted_index  \
# 0    4.593750    -9999.0   -9999.0   -9999.0  12.8125     12.328125
# 1    4.593750    -9999.0   -9999.0   -9999.0  12.8125     12.328125
# 2    2.640625    -9999.0   -9999.0   -9999.0  25.8750     -3.828125
# 3    2.640625    -9999.0   -9999.0   -9999.0  25.8750     -3.828125
# 4    6.015625    -9999.0   -9999.0   -9999.0  23.8750      2.015625
#
#         rh2m  msl_pressure  prec_amount  snow_depth  wind10m.direction  \
# 0   4.281250   1019.562500     0.484375         0.0         244.062500
# 1   4.281250   1019.562500     0.484375         0.0         244.062500
# 2  10.828125   1015.937500     2.796875         0.0          80.859375
# 3  10.828125   1015.937500     2.796875         0.0          80.859375
# 4  10.218750   1018.859375     1.078125         0.0         145.703125
#
#    wind10m.speed    latitud    longitud
# 0       2.671875  39.783730 -100.445882
# 1       2.671875  39.783730 -100.445882
# 2       3.296875 -24.776109  134.755000
# 3       3.296875 -24.776109  134.755000
# 4       2.515625 -28.816624   24.991639

# %%
df_pais_clima.shape
# Out:
# (1352, 72)

# %% [markdown]
# - Guardar los resultados obtenidos en un csv que usaremos en próximos ejercicios de pair programming.

# %%
# Guardamos
df_pais_clima.to_csv("../data/00-ataques-clima.csv")
